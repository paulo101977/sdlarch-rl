# %%
import tempfile

import numpy as np
import gymnasium as gym
from stable_baselines3.common.evaluation import evaluate_policy

from imitation.algorithms import bc
from imitation.algorithms.dagger import SimpleDAggerTrainer
from imitation.policies.serialize import load_policy
from imitation.util.util import make_vec_env

rng = np.random.default_rng(0)
env = make_vec_env(
    "seals:seals/CartPole-v0",
    rng=rng,
)
expert = load_policy(
    "ppo-huggingface",
    organization="HumanCompatibleAI",
    env_name="seals-CartPole-v0",
    venv=env,
)

bc_trainer = bc.BC(
    observation_space=env.observation_space,
    action_space=env.action_space,
    rng=rng,
)
with tempfile.TemporaryDirectory(prefix="dagger_example_") as tmpdir:
    print(tmpdir)
    dagger_trainer = SimpleDAggerTrainer(
        venv=env,
        scratch_dir=tmpdir,
        expert_policy=expert,
        bc_trainer=bc_trainer,
        rng=rng,
    )
    dagger_trainer.train(20_000)

reward, _ = evaluate_policy(dagger_trainer.policy, env, 10)
print("Reward:", reward)
# Out:
# D:\Python311\Lib\site-packages\stable_baselines3\common\save_util.py:166: UserWarning: Could not deserialize object learning_rate. Consider using `custom_objects` argument to replace this object.
# Exception: code() argument 13 must be str, not int
#   warnings.warn(
# D:\Python311\Lib\site-packages\stable_baselines3\common\save_util.py:166: UserWarning: Could not deserialize object clip_range. Consider using `custom_objects` argument to replace this object.
# Exception: code() argument 13 must be str, not int
#   warnings.warn(
# D:\Python311\Lib\site-packages\stable_baselines3\common\save_util.py:166: UserWarning: Could not deserialize object lr_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: code() argument 13 must be str, not int
#   warnings.warn(
# D:\Python311\Lib\site-packages\stable_baselines3\common\save_util.py:449: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   th_object = th.load(file_content, map_location=device)
# C:\Users\paulo\AppData\Local\Temp\dagger_example_j5ej9p6g
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# 0batch [00:00, ?batch/s]
# ---------------------------------
# | batch_size        | 32        |
# | bc/               |           |
# |    batch          | 0         |
# |    ent_loss       | -0.000693 |
# |    entropy        | 0.693     |
# |    epoch          | 0         |
# |    l2_loss        | 0         |
# |    l2_norm        | 72.5      |
# |    loss           | 0.692     |
# |    neglogp        | 0.693     |
# |    prob_true_act  | 0.5       |
# |    samples_so_far | 32        |
# | rollout/          |           |
# |    return_max     | 66        |
# |    return_mean    | 37.8      |
# |    return_min     | 17        |
# |    return_std     | 18.7      |
# ---------------------------------
# 119batch [00:01, 128.12batch/s]
# 238batch [00:02, 136.85batch/s]
# 360batch [00:03, 124.36batch/s]
# 487batch [00:04, 139.40batch/s]
# 500batch [00:04, 115.82batch/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# 0batch [00:00, ?batch/s]
# ---------------------------------
# | batch_size        | 32        |
# | bc/               |           |
# |    batch          | 0         |
# |    ent_loss       | -0.000311 |
# |    entropy        | 0.311     |
# |    epoch          | 0         |
# |    l2_loss        | 0         |
# |    l2_norm        | 96.4      |
# |    loss           | 0.292     |
# |    neglogp        | 0.292     |
# |    prob_true_act  | 0.795     |
# |    samples_so_far | 32        |
# | rollout/          |           |
# |    return_max     | 500       |
# |    return_mean    | 491       |
# |    return_min     | 431       |
# |    return_std     | 22.8      |
# ---------------------------------
# 247batch [00:02, 164.42batch/s]
# 489batch [00:04, 133.90batch/s]
# Epoch 1 of 4
# ---------------------------------
# | batch_size        | 32        |
# | bc/               |           |
# |    batch          | 500       |
# |    ent_loss       | -0.000294 |
# |    entropy        | 0.294     |
# |    epoch          | 2         |
# |    l2_loss        | 0         |
# |    l2_norm        | 150       |
# |    loss           | 0.182     |
# |    neglogp        | 0.183     |
# |    prob_true_act  | 0.852     |
# |    samples_so_far | 16032     |
# | rollout/          |           |
# |    return_max     | 500       |
# |    return_mean    | 500       |
# |    return_min     | 500       |
# |    return_std     | 0         |
# ---------------------------------
# 742batch [00:06, 148.39batch/s]
# 988batch [00:08, 151.11batch/s]
# 1000batch [00:08, 116.45batch/s][A
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# 0batch [00:00, ?batch/s]
# ---------------------------------
# | batch_size        | 32        |
# | bc/               |           |
# |    batch          | 0         |
# |    ent_loss       | -0.000139 |
# |    entropy        | 0.139     |
# |    epoch          | 0         |
# |    l2_loss        | 0         |
# |    l2_norm        | 226       |
# |    loss           | 0.0753    |
# |    neglogp        | 0.0754    |
# |    prob_true_act  | 0.937     |
# |    samples_so_far | 32        |
# | rollout/          |           |
# |    return_max     | 500       |
# |    return_mean    | 500       |
# |    return_min     | 500       |
# |    return_std     | 0         |
# ---------------------------------
# 371batch [00:03, 136.78batch/s]
# 489batch [00:04, 136.61batch/s]
# ---------------------------------
# | batch_size        | 32        |
# | bc/               |           |
# |    batch          | 500       |
# |    ent_loss       | -0.000124 |
# |    entropy        | 0.124     |
# |    epoch          | 1         |
# |    l2_loss        | 0         |
# |    l2_norm        | 280       |
# |    loss           | 0.0657    |
# |    neglogp        | 0.0658    |
# |    prob_true_act  | 0.946     |
# |    samples_so_far | 16032     |
# | rollout/          |           |
# |    return_max     | 500       |
# |    return_mean    | 500       |
# |    return_min     | 500       |
# |    return_std     | 0         |
# ---------------------------------
# 742batch [00:06, 141.96batch/s]
# 988batch [00:08, 150.20batch/s]
# ---------------------------------
# | batch_size        | 32        |
# | bc/               |           |
# |    batch          | 1000      |
# |    ent_loss       | -8.84e-05 |
# |    entropy        | 0.0884    |
# |    epoch          | 2         |
# |    l2_loss        | 0         |
# |    l2_norm        | 323       |
# |    loss           | 0.044     |
# |    neglogp        | 0.0441    |
# |    prob_true_act  | 0.963     |
# |    samples_so_far | 32032     |
# | rollout/          |           |
# |    return_max     | 500       |
# |    return_mean    | 500       |
# |    return_min     | 500       |
# |    return_std     | 0         |
# ---------------------------------
# 1114batch [00:10, 109.43batch/s]
# 1495batch [00:13, 160.36batch/s]
# 1500batch [00:13, 113.97batch/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# 0batch [00:00, ?batch/s]
# ---------------------------------
# | batch_size        | 32        |
# | bc/               |           |
# |    batch          | 0         |
# |    ent_loss       | -9.24e-05 |
# |    entropy        | 0.0924    |
# |    epoch          | 0         |
# |    l2_loss        | 0         |
# |    l2_norm        | 351       |
# |    loss           | 0.0547    |
# |    neglogp        | 0.0548    |
# |    prob_true_act  | 0.955     |
# |    samples_so_far | 32        |
# | rollout/          |           |
# |    return_max     | 500       |
# |    return_mean    | 500       |
# |    return_min     | 500       |
# |    return_std     | 0         |
# ---------------------------------
# 488batch [00:04, 136.52batch/s]
# Epoch 0 of 4
# ---------------------------------
# | batch_size        | 32        |
# | bc/               |           |
# |    batch          | 500       |
# |    ent_loss       | -0.000101 |
# |    entropy        | 0.101     |
# |    epoch          | 1         |
# |    l2_loss        | 0         |
# |    l2_norm        | 378       |
# |    loss           | 0.0981    |
# |    neglogp        | 0.0982    |
# |    prob_true_act  | 0.933     |
# |    samples_so_far | 16032     |
# | rollout/          |           |
# |    return_max     | 500       |
# |    return_mean    | 500       |
# |    return_min     | 500       |
# |    return_std     | 0         |
# ---------------------------------
# 993batch [00:08, 135.26batch/s]
# Epoch 1 of 4
# --------------------------------
# | batch_size        | 32       |
# | bc/               |          |
# |    batch          | 1000     |
# |    ent_loss       | -3.9e-05 |
# |    entropy        | 0.039    |
# |    epoch          | 2        |
# |    l2_loss        | 0        |
# |    l2_norm        | 397      |
# |    loss           | 0.0131   |
# |    neglogp        | 0.0131   |
# |    prob_true_act  | 0.988    |
# |    samples_so_far | 32032    |
# | rollout/          |          |
# |    return_max     | 500      |
# |    return_mean    | 500      |
# |    return_min     | 500      |
# |    return_std     | 0        |
# --------------------------------
# 1496batch [00:12, 156.12batch/s]
# Epoch 2 of 4
# ---------------------------------
# | batch_size        | 32        |
# | bc/               |           |
# |    batch          | 1500      |
# |    ent_loss       | -5.51e-05 |
# |    entropy        | 0.0551    |
# |    epoch          | 3         |
# |    l2_loss        | 0         |
# |    l2_norm        | 414       |
# |    loss           | 0.0454    |
# |    neglogp        | 0.0454    |
# |    prob_true_act  | 0.969     |
# |    samples_so_far | 48032     |
# | rollout/          |           |
# |    return_max     | 500       |
# |    return_mean    | 500       |
# |    return_min     | 500       |
# |    return_std     | 0         |
# ---------------------------------
# 1990batch [00:16, 179.20batch/s]
# 2000batch [00:16, 121.36batch/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1 [00:00<?, ? examples/s]
# 0batch [00:00, ?batch/s]
# ---------------------------------
# | batch_size        | 32        |
# | bc/               |           |
# |    batch          | 0         |
# |    ent_loss       | -4.36e-05 |
# |    entropy        | 0.0436    |
# |    epoch          | 0         |
# |    l2_loss        | 0         |
# |    l2_norm        | 425       |
# |    loss           | 0.0854    |
# |    neglogp        | 0.0855    |
# |    prob_true_act  | 0.96      |
# |    samples_so_far | 32        |
# | rollout/          |           |
# |    return_max     | 500       |
# |    return_mean    | 500       |
# |    return_min     | 500       |
# |    return_std     | 0         |
# ---------------------------------
# 494batch [00:04, 157.71batch/s]
# --------------------------------
# | batch_size        | 32       |
# | bc/               |          |
# |    batch          | 500      |
# |    ent_loss       | -5.7e-05 |
# |    entropy        | 0.057    |
# |    epoch          | 0        |
# |    l2_loss        | 0        |
# |    l2_norm        | 429      |
# |    loss           | 0.0375   |
# |    neglogp        | 0.0375   |
# |    prob_true_act  | 0.972    |
# |    samples_so_far | 16032    |
# | rollout/          |          |
# |    return_max     | 500      |
# |    return_mean    | 500      |
# |    return_min     | 500      |
# |    return_std     | 0        |
# --------------------------------
# 614batch [00:05, 112.27batch/s]
# 987batch [00:08, 140.65batch/s]
# ---------------------------------
# | batch_size        | 32        |
# | bc/               |           |
# |    batch          | 1000      |
# |    ent_loss       | -0.000102 |
# |    entropy        | 0.102     |
# |    epoch          | 1         |
# |    l2_loss        | 0         |
# |    l2_norm        | 430       |
# |    loss           | 0.111     |
# |    neglogp        | 0.111     |
# |    prob_true_act  | 0.933     |
# |    samples_so_far | 32032     |
# | rollout/          |           |
# |    return_max     | 500       |
# |    return_mean    | 500       |
# |    return_min     | 500       |
# |    return_std     | 0         |
# ---------------------------------
# 1238batch [00:10, 134.87batch/s]
# 1486batch [00:12, 159.83batch/s]
# ---------------------------------
# | batch_size        | 32        |
# | bc/               |           |
# |    batch          | 1500      |
# |    ent_loss       | -8.72e-05 |
# |    entropy        | 0.0872    |
# |    epoch          | 2         |
# |    l2_loss        | 0         |
# |    l2_norm        | 432       |
# |    loss           | 0.0457    |
# |    neglogp        | 0.0458    |
# |    prob_true_act  | 0.961     |
# |    samples_so_far | 48032     |
# | rollout/          |           |
# |    return_max     | 500       |
# |    return_mean    | 500       |
# |    return_min     | 500       |
# |    return_std     | 0         |
# ---------------------------------
# 1873batch [00:16, 159.15batch/s]
# 1994batch [00:17, 131.19batch/s]
# ---------------------------------
# | batch_size        | 32        |
# | bc/               |           |
# |    batch          | 2000      |
# |    ent_loss       | -7.58e-05 |
# |    entropy        | 0.0758    |
# |    epoch          | 3         |
# |    l2_loss        | 0         |
# |    l2_norm        | 433       |
# |    loss           | 0.045     |
# |    neglogp        | 0.0451    |
# |    prob_true_act  | 0.964     |
# |    samples_so_far | 64032     |
# | rollout/          |           |
# |    return_max     | 500       |
# |    return_mean    | 500       |
# |    return_min     | 500       |
# |    return_std     | 0         |
# ---------------------------------
# 2487batch [00:21, 136.01batch/s]
# 2500batch [00:21, 117.24batch/s]
# Reward: 500.0
